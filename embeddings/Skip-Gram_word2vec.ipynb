# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:20, 1.53MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
totalWords = len(words)
uniqueWords = len(set(words))
print("Total words: {}".format(totalWords))
print("Unique words: {}".format(uniqueWords))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

word_counts = Counter(int_words)
t =  1e-5   
frequencies = {word: (count / totalWords) for word, count in word_counts.items()}
prob_drop = {word: 1 - np.sqrt(t / frequencies[word]) for word in word_counts}

train_words = [word for word in int_words if random.random() < (1 - prob_drop[word])] # The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R if(idx + R) < len(words) else len(words) - 1
    target_words = set(words[start:idx] + words[idx+1:stop+1])   
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, name='inputs', shape=[None])
    labels = tf.placeholder(tf.int32, name='labels', shape=[None,None])

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 300 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed =  tf.nn.embedding_lookup(embedding, inputs)  # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.7830 0.2252 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.7134 0.1988 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.6124 0.2086 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.7132 0.2068 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.6274 0.2017 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.6317 0.2008 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.6539 0.2034 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.6097 0.2034 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.5551 0.2019 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.5043 0.2024 sec/batch
# Nearest to their: french, wholeheartedly, canaanites, acrobatic, electromagnets, chronicles, computable, offices,
# Nearest to it: ilbo, growth, gila, highlands, airway, steamed, armstrong, khaled,
# Nearest to world: slave, cass, counterintelligence, provocative, lie, wholes, trust, st,
# Nearest to an: recorded, scored, palahniuk, succulent, antibody, freethinker, thyroid, ordained,
# Nearest to of: facilitate, expiring, oxidizes, sheep, propylaea, changed, dq, apprenticeship,
# Nearest to nine: aram, vanquished, suspicious, donna, duquesne, daito, s, moot,
# Nearest to during: rigg, burgers, palsy, hayden, gilman, stenosis, illuminations, ensuing,
# Nearest to while: lake, lessening, quito, two, stanfield, astin, camels, calories,
# Nearest to dr: truss, rorty, decode, eating, january, ravalomanana, computations, jackpots,
# Nearest to nobel: abadan, z, leeway, vum, congressman, mcgowan, inhibitors, metered,
# Nearest to except: irwin, radically, wastes, replicates, conform, placename, gallifrey, focussing,
# Nearest to animals: vilas, infidelity, canadian, longbowmen, laurales, carlow, veer, rosso,
# Nearest to scale: pinyin, autobiographies, campaigner, barbecued, pion, offensive, amun, ocarina,
# Nearest to san: rerun, bivouac, belfort, casteljau, oration, solubility, bakassi, buda,
# Nearest to mainly: significance, monsanto, alberti, newsletter, kaliningrad, jeux, gaon, institutional,
# Nearest to prince: blacklisting, arcturus, shrublands, sifre, punta, jani, monuments, pedagogic,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5832 0.1933 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4588 0.1925 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3715 0.2057 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2832 0.2071 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2488 0.2067 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.2056 0.2072 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1326 0.2037 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.1419 0.1873 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0730 0.1840 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0381 0.1838 sec/batch
# Nearest to their: french, offices, canaanites, wholeheartedly, chronicles, others, computable, twist,
# Nearest to it: growth, ilbo, steamed, highlands, written, airway, armstrong, citizens,
# Nearest to world: slave, cass, trust, lie, st, relies, regular, wanted,
# Nearest to an: recorded, scored, material, she, ordained, palahniuk, the, illegal,
# Nearest to of: facilitate, conducted, changed, oo, sheep, amount, secure, denote,
# Nearest to nine: aram, donna, s, suspicious, vanquished, roman, francis, album,
# Nearest to during: rigg, simultaneously, burgers, palsy, ensuing, hosts, hayden, aotearoa,
# Nearest to while: lake, lessening, stanfield, unions, admired, quito, calories, distinguished,
# Nearest to dr: truss, rorty, january, decode, eating, ravalomanana, understand, computations,
# Nearest to nobel: z, century, inhibitors, congressman, leeway, album, courts, mond,
# Nearest to except: irwin, radically, conform, wastes, disaster, derive, oil, placename,
# Nearest to animals: canadian, infidelity, carlow, vilas, longbowmen, observance, corresponding, musicals,
# Nearest to scale: pinyin, barbecued, autobiographies, offensive, campaigner, selection, editorial, ocarina,
# Nearest to san: rerun, bivouac, subversive, belfort, bakassi, casteljau, scoring, charisma,
# Nearest to mainly: significance, newsletter, monsanto, alberti, institutional, reunified, kickoff, kaliningrad,
# Nearest to prince: arcturus, blacklisting, shrublands, monuments, moulton, tends, pedagogic, punta,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9751 0.1857 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9583 0.1841 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9277 0.1888 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.9334 0.1822 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8667 0.1845 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8833 0.1853 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8466 0.1823 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8567 0.1812 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8583 0.1817 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.8100 0.1820 sec/batch
# Nearest to their: french, wholeheartedly, canaanites, offices, reunited, acrobatic, electromagnets, twist,
# Nearest to it: ilbo, growth, steamed, airway, circuitry, wedge, gila, defended,
# Nearest to world: slave, cass, trust, provocative, poland, st, regular, lie,
# Nearest to an: ordained, recorded, scored, thyroid, material, speculate, vehicles, palahniuk,
# Nearest to of: facilitate, conducted, denote, dq, sheep, changed, apprenticeship, substitutes,
# Nearest to nine: aram, donna, francis, duquesne, album, s, suspicious, vanquished,
# Nearest to during: ensuing, rigg, stenosis, palsy, simultaneously, hayden, surround, gilman,
# Nearest to while: unions, lake, calories, quito, admired, stanfield, perpetuate, lessening,
# Nearest to dr: truss, rorty, decode, gilpin, january, revoked, earl, eating,
# Nearest to nobel: congressman, z, leeway, inhibitors, boris, prize, album, gutenberg,
# Nearest to except: irwin, radically, wastes, conform, focussing, oil, disaster, replicates,
# Nearest to animals: canadian, infidelity, corresponding, observance, carlow, musicals, vilas, longbowmen,
# Nearest to scale: pinyin, barbecued, campaigner, autobiographies, selection, offensive, editorial, ocarina,
# Nearest to san: rerun, bivouac, subversive, charisma, scoring, buda, belfort, oration,
# Nearest to mainly: significance, monsanto, newsletter, alberti, institutional, kickoff, uthman, kaliningrad,
# Nearest to prince: arcturus, blacklisting, shrublands, moulton, monuments, shaughnessy, diocletian, lia,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8432 0.1833 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.8198 0.1814 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7821 0.1823 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7639 0.1820 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7772 0.1831 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7351 0.1823 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7451 0.1819 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7848 0.1812 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7294 0.1816 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.7073 0.1812 sec/batch
# Nearest to their: french, reunited, canaanites, jar, wholeheartedly, electromagnets, offices, headwear,
# Nearest to it: ilbo, growth, steamed, airway, circuitry, hitchhikers, niece, wedge,
# Nearest to world: slave, cass, duet, trust, provocative, micah, counterintelligence, regular,
# Nearest to an: ordained, recorded, thyroid, scored, antibody, palahniuk, speculate, posters,
# Nearest to of: conducted, facilitate, dq, denote, fatherland, secure, tolerable, kcal,
# Nearest to nine: donna, francis, aram, s, vanquished, conn, actor, duquesne,
# Nearest to during: ensuing, stenosis, rigg, hayden, surround, gilman, mideast, palsy,
# Nearest to while: calories, unions, quito, admired, lake, ligatures, perpetuate, messiaen,
# Nearest to dr: truss, gilpin, earl, january, rorty, revoked, decode, ravalomanana,
# Nearest to nobel: prize, congressman, mathematician, laureate, boris, leeway, aeronautical, metered,
# Nearest to except: irwin, radically, conform, heaps, wastes, focussing, placename, disaster,
# Nearest to animals: infidelity, carlow, canadian, vilas, veer, corresponding, musicals, longbowmen,
# Nearest to scale: pinyin, barbecued, autobiographies, campaigner, selection, offensive, deciphered, boi,
# Nearest to san: rerun, scoring, bivouac, oration, buda, charisma, belfort, subversive,
# Nearest to mainly: monsanto, alberti, newsletter, significance, kaliningrad, institutional, uthman, kickoff,
# Nearest to prince: blacklisting, arcturus, shrublands, moulton, sifre, shaughnessy, monuments, pedagogic,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.7265 0.1830 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.7132 0.1816 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6166 0.1820 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6344 0.1823 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6565 0.1833 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6589 0.1828 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6185 0.1330 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5362 0.1827 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5083 0.1819 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4906 0.1827 sec/batch
# Nearest to their: wholeheartedly, jar, reunited, canaanites, peckinpah, acrobatic, electromagnets, respondents,
# Nearest to it: ilbo, steamed, airway, growth, chamber, circuitry, wedge, distress,
# Nearest to world: slave, cass, trust, duet, wholes, lyne, micah, counterintelligence,
# Nearest to an: antibody, ordained, thyroid, speculate, recorded, scored, sle, palahniuk,
# Nearest to of: conducted, dq, facilitate, denote, twinning, substitutes, fatherland, tolerable,
# Nearest to nine: musician, actor, donna, francis, aram, conn, s, montgomery,
# Nearest to during: ensuing, stenosis, mideast, rigg, gilman, hayden, surround, palsy,
# Nearest to while: calories, unions, quito, ligatures, permissions, lake, perpetuate, messiaen,
# Nearest to dr: truss, gilpin, earl, rorty, revoked, ravalomanana, january, rosenberg,
# Nearest to nobel: prize, congressman, mathematician, laureate, recipient, boris, percy, lenz,
# Nearest to except: irwin, radically, heaps, conform, wastes, focussing, replicates, placename,
# Nearest to animals: carlow, infidelity, vilas, veer, corresponding, observance, musicals, longbowmen,
# Nearest to scale: pinyin, barbecued, selection, autobiographies, deciphered, campaigner, objects, boi,
# Nearest to san: rerun, bivouac, scoring, centrosomes, oration, buda, belfort, bakassi,
# Nearest to mainly: monsanto, alberti, significance, newsletter, kaliningrad, uthman, institutional, kickoff,
# Nearest to prince: blacklisting, shrublands, sifre, moulton, arcturus, scottish, jani, untethered,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4724 0.1825 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4672 0.1816 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4047 0.1816 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5092 0.1817 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4603 0.1830 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4514 0.1828 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4335 0.1819 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3729 0.1820 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4123 0.1825 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.3594 0.1819 sec/batch
# Nearest to their: reunited, jar, wholeheartedly, electromagnets, canaanites, peckinpah, acrobatic, headwear,
# Nearest to it: ilbo, steamed, airway, growth, is, distress, circuitry, grassmann,
# Nearest to world: slave, cass, trust, lyne, duet, wholes, capital, skiing,
# Nearest to an: antibody, ordained, thyroid, recorded, speculate, succulent, posters, palahniuk,
# Nearest to of: facilitate, dq, tolerable, kcal, conducted, mauritania, substitutes, denote,
# Nearest to nine: s, donna, aram, musician, vanquished, zero, conn, rossetti,
# Nearest to during: ensuing, mideast, stenosis, rigg, gilman, palsy, authoritarianism, alfa,
# Nearest to while: calories, unions, quito, messiaen, ligatures, perpetuate, permissions, lake,
# Nearest to dr: truss, gilpin, earl, rorty, ravalomanana, judaica, rosenberg, revoked,
# Nearest to nobel: prize, congressman, mathematician, laureate, boris, recipient, percy, metered,
# Nearest to except: irwin, heaps, radically, conform, placename, crystallographic, replicates, focussing,
# Nearest to animals: carlow, vilas, corresponding, infidelity, canadian, veer, observance, elitist,
# Nearest to scale: pinyin, barbecued, selection, autobiographies, deciphered, campaigner, boi, egon,
# Nearest to san: rerun, centrosomes, scoring, buda, bakassi, oration, hall, bivouac,
# Nearest to mainly: monsanto, alberti, significance, kaliningrad, newsletter, uthman, kickoff, leutze,
# Nearest to prince: blacklisting, sifre, shrublands, shaughnessy, moulton, lorraine, monuments, lia,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4648 0.1827 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3929 0.1817 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4486 0.1814 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3810 0.1822 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3962 0.1819 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4215 0.1817 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3529 0.1819 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3671 0.1811 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3922 0.1822 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.4048 0.1817 sec/batch
# Nearest to their: reunited, jar, canaanites, headwear, electromagnets, peckinpah, wholeheartedly, acrobatic,
# Nearest to it: ilbo, steamed, airway, growth, grassmann, circuitry, urbane, niece,
# Nearest to world: slave, cass, trust, lyne, capital, wholes, counterintelligence, duet,
# Nearest to an: antibody, ordained, recorded, speculate, thyroid, succulent, sle, simplest,
# Nearest to of: kcal, tolerable, apprenticeship, substitutes, changed, conducted, dq, avid,
# Nearest to nine: donna, musician, s, zero, rossetti, francis, conn, aram,
# Nearest to during: ensuing, mideast, stenosis, rigg, palsy, alfa, gilman, authoritarianism,
# Nearest to while: calories, messiaen, quito, unions, lake, permissions, gwr, perpetuate,
# Nearest to dr: truss, rosenberg, gilpin, earl, ravalomanana, january, floundered, rorty,
# Nearest to nobel: prize, congressman, mathematician, laureate, boris, percy, recipient, metered,
# Nearest to except: irwin, heaps, radically, placename, conform, gallifrey, crystallographic, replicates,
# Nearest to animals: carlow, vilas, infidelity, canadian, veer, corresponding, hindsight, musicals,
# Nearest to scale: pinyin, barbecued, autobiographies, selection, deciphered, egon, deficit, campaigner,
# Nearest to san: centrosomes, rerun, scoring, oration, bandleader, bakassi, mira, ccel,
# Nearest to mainly: monsanto, alberti, significance, kaliningrad, uthman, newsletter, jeux, leutze,
# Nearest to prince: blacklisting, sifre, shaughnessy, shrublands, whom, moulton, lorraine, constantinople,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3755 0.1827 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3940 0.1823 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3558 0.1837 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3379 0.1817 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3535 0.1834 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3554 0.1822 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3795 0.1869 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3668 0.1809 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.2965 0.1822 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3286 0.1814 sec/batch
# Nearest to their: reunited, canaanites, choosing, headwear, ligaments, wholeheartedly, jar, others,
# Nearest to it: ilbo, steamed, is, airway, niece, shores, teas, growth,
# Nearest to world: slave, cass, trust, capital, lyne, delano, wholes, micah,
# Nearest to an: antibody, ordained, recorded, thyroid, succulent, speculate, choose, discursive,
# Nearest to of: kcal, xxxg, facilitate, conducted, substitutes, changed, secure, fatherland,
# Nearest to nine: zero, four, s, donna, aram, lyndon, rossetti, duquesne,
# Nearest to during: ensuing, mideast, stenosis, rigg, palsy, authoritarianism, alfa, nocturne,
# Nearest to while: calories, messiaen, unions, quito, permissions, lake, gwr, differentia,
# Nearest to dr: truss, rosenberg, gilpin, earl, ravalomanana, january, beaumont, rorty,
# Nearest to nobel: prize, congressman, mathematician, laureate, recipient, boris, lenz, percy,
# Nearest to except: irwin, heaps, radically, placename, gallifrey, replicates, crystallographic, conform,
# Nearest to animals: carlow, infidelity, vilas, canadian, hindsight, veer, elitist, observance,
# Nearest to scale: pinyin, barbecued, deficit, autobiographies, selection, deciphered, spurred, campaigner,
# Nearest to san: centrosomes, scoring, rerun, ccel, mira, bakassi, oration, bandleader,
# Nearest to mainly: monsanto, significance, alberti, kaliningrad, newsletter, jeux, uthman, leutze,
# Nearest to prince: blacklisting, sifre, shrublands, remarriage, shaughnessy, whom, monuments, lorraine,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3170 0.1828 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3016 0.1820 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3717 0.1823 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3621 0.1819 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3742 0.1819 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2976 0.1814 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3081 0.1805 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3294 0.1819 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.1927 0.1820 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3004 0.1808 sec/batch
# Nearest to their: reunited, choosing, rutles, canaanites, headwear, ligaments, peckinpah, jar,
# Nearest to it: steamed, ilbo, airway, niece, wedge, urbane, circuitry, chamber,
# Nearest to world: slave, cass, capital, trust, wholes, micah, delano, lyne,
# Nearest to an: antibody, ordained, thyroid, recorded, choose, succulent, speculate, palahniuk,
# Nearest to of: xxxg, kcal, mauritania, conducted, tolerable, facilitate, substitutes, maps,
# Nearest to nine: four, zero, s, one, musician, rossetti, lyndon, conn,
# Nearest to during: ensuing, mideast, rigg, stenosis, authoritarianism, alfa, palsy, typhoons,
# Nearest to while: calories, messiaen, unions, quito, lake, permissions, gwr, calorie,
# Nearest to dr: rosenberg, gilpin, truss, earl, judaica, ravalomanana, airmen, beaumont,
# Nearest to nobel: prize, mathematician, recipient, laureate, congressman, boris, percy, aeronautical,
# Nearest to except: irwin, heaps, radically, gallifrey, placename, conform, crystallographic, liliopsida,
# Nearest to animals: carlow, infidelity, vilas, observance, ginsberg, hindsight, workingmen, musicals,
# Nearest to scale: barbecued, pinyin, deficit, ounces, deciphered, autobiographies, selection, boi,
# Nearest to san: centrosomes, rerun, ccel, scoring, mira, bandleader, bakassi, oration,
# Nearest to mainly: monsanto, alberti, significance, kaliningrad, newsletter, uthman, leutze, zafy,
# Nearest to prince: blacklisting, sifre, shrublands, shaughnessy, whom, remarriage, monuments, constantinople,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2906 0.1848 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2760 0.1816 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3130 0.0831 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2179 0.1809 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.1932 0.1812 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1705 0.1817 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1484 0.1805 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1720 0.1805 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.1661 0.1822 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1340 0.1819 sec/batch
# Nearest to their: reunited, choosing, headwear, rutles, canaanites, ligaments, peckinpah, jar,
# Nearest to it: steamed, ilbo, shores, urbane, is, wedge, airway, odin,
# Nearest to world: slave, trust, capital, cass, wholes, micah, delano, lyne,
# Nearest to an: antibody, recorded, thyroid, choose, ordained, clearing, taka, palahniuk,
# Nearest to of: xxxg, facilitate, mauritania, kcal, substitutes, tallapoosa, conducted, tolerable,
# Nearest to nine: zero, four, s, lyndon, one, rossetti, blacki, duquesne,
# Nearest to during: ensuing, mideast, stenosis, authoritarianism, alfa, palsy, rigg, typhoons,
# Nearest to while: calories, quito, messiaen, unions, lake, nausica, calorie, partaking,
# Nearest to dr: rosenberg, gilpin, truss, earl, judaica, ravalomanana, irresponsible, sophist,
# Nearest to nobel: prize, recipient, mathematician, laureate, congressman, boris, aeronautical, percy,
# Nearest to except: heaps, irwin, radically, gallifrey, placename, conform, crystallographic, liliopsida,
# Nearest to animals: carlow, infidelity, observance, ginsberg, vilas, kylie, hindsight, veer,
# Nearest to scale: barbecued, pinyin, offensive, campaigner, deciphered, boi, deficit, selection,
# Nearest to san: centrosomes, ccel, rerun, scoring, mira, bakassi, nevada, memel,
# Nearest to mainly: monsanto, alberti, significance, kaliningrad, newsletter, uthman, leutze, gaon,
# Nearest to prince: blacklisting, sifre, shaughnessy, shrublands, moulton, remarriage, constantinople, eudes,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2287 0.1828 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1859 0.1812 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.1946 0.1816 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1245 0.1822 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1504 0.1812 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1460 0.1812 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1297 0.1819 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1519 0.1816 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1506 0.1811 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1292 0.1819 sec/batch
# Nearest to their: reunited, choosing, headwear, ligaments, rutles, canaanites, jar, meditator,
# Nearest to it: steamed, is, shores, odin, ilbo, wedge, growth, airway,
# Nearest to world: slave, trust, cass, capital, skiing, wholes, delano, micah,
# Nearest to an: antibody, thyroid, recorded, choose, ordained, the, palahniuk, discursive,
# Nearest to of: substitutes, facilitate, kcal, xxxg, secure, theologically, sincerely, tallapoosa,
# Nearest to nine: zero, four, s, lyndon, one, pennant, rossetti, duquesne,
# Nearest to during: ensuing, mideast, stenosis, authoritarianism, palsy, rigg, alfa, gilman,
# Nearest to while: calories, quito, unions, lake, messiaen, nausica, permissions, partaking,
# Nearest to dr: rosenberg, truss, gilpin, earl, judaica, wagnerites, diarists, enlighten,
# Nearest to nobel: prize, mathematician, recipient, laureate, congressman, boris, aeronautical, lenz,
# Nearest to except: heaps, irwin, radically, conform, crystallographic, gallifrey, liliopsida, placename,
# Nearest to animals: infidelity, carlow, canadian, ginsberg, hindsight, vilas, clothed, observance,
# Nearest to scale: barbecued, pinyin, conjuction, campaigner, deciphered, boi, offensive, deficit,
# Nearest to san: ccel, centrosomes, bakassi, mira, rerun, scoring, jose, nevada,
# Nearest to mainly: monsanto, significance, newsletter, alberti, kaliningrad, fueling, leutze, uthman,
# Nearest to prince: blacklisting, remarriage, sifre, whom, lia, shaughnessy, lorraine, cathal,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1429 0.1828 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2115 0.1809 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1690 0.1820 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1178 0.1812 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1376 0.1817 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1576 0.1814 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1706 0.1819 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1302 0.1816 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.0927 0.1814 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1593 0.1814 sec/batch
# Nearest to their: reunited, choosing, headwear, canaanites, ligaments, rutles, jar, wholeheartedly,
# Nearest to it: is, shores, niece, steamed, wedge, ilbo, odin, growth,
# Nearest to world: slave, capital, trust, cass, relies, micah, divinity, wholes,
# Nearest to an: antibody, choose, recorded, the, ordained, thyroid, uphold, arkham,
# Nearest to of: kcal, substitutes, xxxg, secure, conducted, facilitate, theologically, mauritania,
# Nearest to nine: zero, four, one, s, three, five, two, orbison,
# Nearest to during: ensuing, mideast, stenosis, authoritarianism, palsy, alfa, rigg, typhoons,
# Nearest to while: calories, quito, messiaen, unions, nausica, lake, babysitter, partaking,
# Nearest to dr: rosenberg, gilpin, truss, earl, enlighten, judaica, diarists, sophist,
# Nearest to nobel: prize, laureate, congressman, recipient, mathematician, boris, aeronautical, lenz,
# Nearest to except: heaps, irwin, gallifrey, radically, placename, conform, whitepapers, liliopsida,
# Nearest to animals: infidelity, carlow, hindsight, canadian, vilas, clothed, ginsberg, kylie,
# Nearest to scale: barbecued, pinyin, campaigner, conjuction, roche, inflows, boi, chiba,
# Nearest to san: ccel, centrosomes, mira, bakassi, rerun, nevada, scoring, demeaning,
# Nearest to mainly: monsanto, significance, alberti, newsletter, leutze, fueling, uthman, kaliningrad,
# Nearest to prince: blacklisting, whom, remarriage, gustloff, sophia, sifre, diocletian, citywide,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1660 0.1825 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1407 0.1812 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1515 0.1814 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1581 0.1814 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1239 0.1812 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1176 0.1816 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1708 0.1811 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.0936 0.1831 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1791 0.1827 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1828 0.1812 sec/batch
# Nearest to their: reunited, headwear, canaanites, rutles, choosing, ligaments, bloodthirsty, ballots,
# Nearest to it: niece, is, steamed, shores, odin, persecutions, defended, wedge,
# Nearest to world: micah, capital, cass, slave, trust, delano, sovatsky, divinity,
# Nearest to an: antibody, recorded, the, ordained, choose, uphold, discursive, ramirez,
# Nearest to of: substitutes, conducted, theologically, lublin, secure, xxxg, penned, sextilis,
# Nearest to nine: zero, four, one, s, two, three, five, six,
# Nearest to during: ensuing, mideast, alfa, authoritarianism, stenosis, rigg, gilman, palsy,
# Nearest to while: quito, messiaen, calories, unions, donelson, partaking, lake, gwr,
# Nearest to dr: rosenberg, gilpin, earl, gideon, wagnerites, diarists, enlighten, truss,
# Nearest to nobel: prize, recipient, laureate, congressman, mathematician, boris, aeronautical, metered,
# Nearest to except: heaps, irwin, gallifrey, placename, radically, whitepapers, conform, liliopsida,
# Nearest to animals: infidelity, carlow, ginsberg, clothed, vilas, kylie, canadian, hindsight,
# Nearest to scale: barbecued, pinyin, inflows, campaigner, conjuction, chiba, boi, spurred,
# Nearest to san: ccel, mira, centrosomes, bakassi, rerun, jose, scoring, katy,
# Nearest to mainly: monsanto, significance, newsletter, alberti, gaon, lotus, leutze, fueling,
# Nearest to prince: blacklisting, gustloff, whom, remarriage, lia, shaughnessy, sophia, cathal,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2009 0.1820 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1439 0.1809 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1108 0.1814 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1344 0.1809 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0351 0.1819 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1109 0.1814 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1071 0.1812 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1151 0.1812 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1570 0.0350 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0817 0.1814 sec/batch
# Nearest to their: reunited, headwear, canaanites, choosing, rutles, ballots, bloodthirsty, dress,
# Nearest to it: steamed, shores, is, wedge, niece, exteriors, interconnectedness, odin,
# Nearest to world: micah, capital, skiing, cass, slave, trust, wholes, queensberry,
# Nearest to an: antibody, the, thyroid, recorded, choose, ordained, discursive, uphold,
# Nearest to of: xxxg, conducted, substitutes, theologically, mauritania, gorbachev, historic, secure,
# Nearest to nine: zero, four, one, s, two, three, five, eight,
# Nearest to during: ensuing, mideast, authoritarianism, stenosis, alfa, palsy, rigg, gilman,
# Nearest to while: calories, unions, messiaen, quito, permissions, calorie, nausica, encampments,
# Nearest to dr: rosenberg, gilpin, earl, diarists, exotics, enlighten, truss, unauthorized,
# Nearest to nobel: prize, recipient, laureate, congressman, mathematician, boris, aeronautical, metered,
# Nearest to except: heaps, irwin, gallifrey, placename, crystallographic, liliopsida, radically, whitepapers,
# Nearest to animals: infidelity, carlow, clothed, kylie, musicals, canadian, mop, wolf,
# Nearest to scale: barbecued, pinyin, chiba, inflows, conjuction, deciphered, tone, harder,
# Nearest to san: ccel, mira, bakassi, jose, centrosomes, rerun, ocho, scoring,
# Nearest to mainly: monsanto, significance, lotus, newsletter, alberti, fueling, leutze, gaon,
# Nearest to prince: blacklisting, gustloff, sophia, lia, moulton, cathal, shaughnessy, desired,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0283 0.1822 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0273 0.1820 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0340 0.1816 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0002 0.1828 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0470 0.1809 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 3.9952 0.1814 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0381 0.1817 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0495 0.1812 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0931 0.1823 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0076 0.1819 sec/batch
# Nearest to their: canaanites, headwear, reunited, choosing, molded, ballots, ligaments, rutles,
# Nearest to it: is, shores, steamed, wedge, niece, kittyhawk, persecutions, urbane,
# Nearest to world: skiing, capital, cass, borman, micah, delano, slave, trust,
# Nearest to an: antibody, the, thyroid, recorded, choose, as, ordained, discursive,
# Nearest to of: substitutes, conducted, the, kcal, theologically, facilitate, xxxg, by,
# Nearest to nine: zero, four, one, s, three, two, five, six,
# Nearest to during: ensuing, mideast, authoritarianism, alfa, stenosis, palsy, typhoons, coalition,
# Nearest to while: unions, calories, messiaen, quito, partaking, calorie, lake, flicker,
# Nearest to dr: rosenberg, diarists, exotics, gilpin, earl, truss, enlighten, judaica,
# Nearest to nobel: prize, recipient, laureate, congressman, boris, mathematician, metered, skelton,
# Nearest to except: irwin, heaps, gallifrey, placename, indicted, liliopsida, crystallographic, radically,
# Nearest to animals: infidelity, carlow, canadian, kylie, chordata, mop, ginsberg, clothed,
# Nearest to scale: barbecued, pinyin, chiba, conjuction, inflows, campaigner, woodman, pion,
# Nearest to san: jose, ccel, francisco, bakassi, mira, centrosomes, nevada, dearborn,
# Nearest to mainly: monsanto, significance, lotus, fueling, alberti, newsletter, leutze, gaon,
# Nearest to prince: blacklisting, gustloff, sophia, whom, shaughnessy, lia, seating, cathal,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9528 0.1834 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.9953 0.1816 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9840 0.1819 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0145 0.1820 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0448 0.1811 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0082 0.1819 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0223 0.1822 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0738 0.1811 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0168 0.1820 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0050 0.1814 sec/batch
# Nearest to their: headwear, canaanites, ballots, molded, ligaments, reunited, cephalopods, choosing,
# Nearest to it: is, shores, persecutions, anticonvulsant, kittyhawk, steamed, niece, odin,
# Nearest to world: capital, skiing, cass, divinity, trust, micah, borman, relies,
# Nearest to an: the, antibody, thyroid, recorded, choose, as, discursive, uphold,
# Nearest to of: substitutes, the, kcal, conducted, theologically, xxxg, significance, facilitate,
# Nearest to nine: zero, four, one, three, two, s, five, six,
# Nearest to during: ensuing, mideast, authoritarianism, palsy, stenosis, typhoons, alfa, rigg,
# Nearest to while: calories, unions, quito, calorie, partaking, flicker, messiaen, permissions,
# Nearest to dr: rosenberg, diarists, exotics, earl, gilpin, enlighten, truss, leland,
# Nearest to nobel: prize, laureate, recipient, congressman, mathematician, boris, metered, skelton,
# Nearest to except: irwin, heaps, gallifrey, placename, whitepapers, liliopsida, indicted, infield,
# Nearest to animals: infidelity, carlow, canadian, chordata, kylie, clothed, mop, ginsberg,
# Nearest to scale: barbecued, chiba, conjuction, pinyin, campaigner, inflows, pion, woodman,
# Nearest to san: jose, ccel, mira, bakassi, francisco, centrosomes, nevada, dearborn,
# Nearest to mainly: monsanto, lotus, alberti, fueling, significance, newsletter, gaon, linden,
# Nearest to prince: blacklisting, gustloff, seating, whom, sophia, lia, citywide, cathal,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0350 0.1820 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0491 0.1820 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0527 0.1814 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0087 0.1817 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0451 0.1805 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0408 0.1811 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0326 0.1814 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0194 0.1820 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0423 0.1814 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0679 0.1819 sec/batch
# Nearest to their: canaanites, headwear, ballots, reunited, status, rutles, choosing, molded,
# Nearest to it: is, shores, persecutions, niece, kittyhawk, odin, steamed, quadrillion,
# Nearest to world: capital, skiing, cass, micah, queensberry, trust, borman, divinity,
# Nearest to an: antibody, the, uphold, choose, recorded, as, discursive, thyroid,
# Nearest to of: the, conducted, theologically, by, kcal, substitutes, xxxg, and,
# Nearest to nine: zero, four, one, three, two, six, five, s,
# Nearest to during: ensuing, mideast, authoritarianism, alfa, palsy, coalition, stenosis, sunga,
# Nearest to while: calories, unions, messiaen, partaking, quito, flicker, permissions, donelson,
# Nearest to dr: rosenberg, diarists, exotics, earl, gilpin, gideon, leland, enlighten,
# Nearest to nobel: prize, laureate, recipient, congressman, boris, mathematician, metered, myrdal,
# Nearest to except: heaps, whitepapers, placename, irwin, gallifrey, indicted, liliopsida, crystallographic,
# Nearest to animals: infidelity, canadian, carlow, clothed, mop, chordata, paraphyletic, kylie,
# Nearest to scale: barbecued, inflows, conjuction, chiba, campaigner, metal, pion, pinyin,
# Nearest to san: ccel, mira, bakassi, jose, centrosomes, francisco, unlocked, ocho,
# Nearest to mainly: monsanto, significance, fueling, gaon, alberti, lotus, linden, newsletter,
# Nearest to prince: gustloff, whom, sophia, blacklisting, seating, citywide, navarro, desired,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0110 0.1823 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9787 0.1816 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0014 0.1820 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0590 0.1817 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0593 0.1817 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.0783 0.1816 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0813 0.1817 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 3.9981 0.1808 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0151 0.1811 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0036 0.1817 sec/batch
# Nearest to their: headwear, canaanites, reunited, ballots, rutles, molded, dress, ligaments,
# Nearest to it: is, shores, persecutions, quadrillion, kittyhawk, niece, lusitania, steamed,
# Nearest to world: cass, skiing, capital, borman, micah, trust, sonja, queensberry,
# Nearest to an: antibody, the, recorded, choose, thyroid, as, uphold, discursive,
# Nearest to of: the, conducted, theologically, xxxg, kcal, facilitate, substitutes, dq,
# Nearest to nine: four, zero, one, two, three, six, five, eight,
# Nearest to during: ensuing, mideast, authoritarianism, alfa, sunga, rigg, coalition, stenosis,
# Nearest to while: calories, unions, permissions, messiaen, quito, flicker, partaking, phocas,
# Nearest to dr: rosenberg, diarists, exotics, gideon, gilpin, earl, enlighten, leland,
# Nearest to nobel: prize, laureate, recipient, congressman, boris, mathematician, metered, myrdal,
# Nearest to except: heaps, placename, liliopsida, gallifrey, irwin, crystallographic, whitepapers, treize,
# Nearest to animals: infidelity, canadian, carlow, mop, clothed, kylie, chordata, burrow,
# Nearest to scale: barbecued, inflows, conjuction, tone, campaigner, woodman, metal, spurred,
# Nearest to san: ccel, jose, mira, francisco, bakassi, centrosomes, ocho, chicano,
# Nearest to mainly: monsanto, lotus, gaon, alberti, fueling, significance, whitlock, newsletter,
# Nearest to prince: gustloff, sophia, blacklisting, whom, seating, citywide, navarro, throne,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9630 0.1819 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0041 0.1822 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0208 0.1819 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.9795 0.1820 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0421 0.1812 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0139 0.1666 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9797 0.1811 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9651 0.1816 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9978 0.1803 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9271 0.1827 sec/batch
# Nearest to their: headwear, canaanites, ballots, reunited, choosing, molded, rutles, cephalopods,
# Nearest to it: shores, is, persecutions, lusitania, niece, kittyhawk, urbane, quadrillion,
# Nearest to world: skiing, borman, cass, capital, micah, vikings, queensberry, trust,
# Nearest to an: antibody, the, thyroid, as, recorded, choose, illegal, full,
# Nearest to of: the, theologically, xxxg, at, conducted, and, by, as,
# Nearest to nine: four, one, zero, two, six, three, five, eight,
# Nearest to during: mideast, ensuing, authoritarianism, sunga, alfa, stenosis, coalition, first,
# Nearest to while: calories, partaking, unions, phocas, permissions, messiaen, flicker, calorie,
# Nearest to dr: rosenberg, diarists, exotics, gilpin, earl, gideon, leland, enlighten,
# Nearest to nobel: prize, laureate, recipient, boris, mathematician, congressman, myrdal, skelton,
# Nearest to except: heaps, irwin, placename, gallifrey, crystallographic, liliopsida, whitepapers, treize,
# Nearest to animals: infidelity, canadian, chordata, carlow, clothed, ginsberg, wolf, kylie,
# Nearest to scale: barbecued, tone, conjuction, inflows, chiba, woodman, ensembles, deciphered,
# Nearest to san: ccel, jose, francisco, mira, bakassi, centrosomes, ocho, unlocked,
# Nearest to mainly: monsanto, lotus, gaon, alberti, significance, fueling, bovines, whitlock,
# Nearest to prince: gustloff, sophia, blacklisting, whom, desired, shaughnessy, seating, navarro,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9446 0.1825 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9430 0.1808 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9648 0.1809 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9566 0.1817 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9994 0.1817 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9907 0.1820 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8958 0.1822 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9467 0.1819 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9206 0.1820 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9436 0.1809 sec/batch
# Nearest to their: headwear, canaanites, ballots, reunited, choosing, cephalopods, rutles, molded,
# Nearest to it: is, shores, kittyhawk, quadrillion, persecutions, wedge, crossword, odin,
# Nearest to world: skiing, capital, borman, cass, micah, trust, drops, vikings,
# Nearest to an: antibody, the, thyroid, as, illegal, recorded, choose, ordained,
# Nearest to of: the, theologically, as, and, substitutes, xxxg, facilitate, kcal,
# Nearest to nine: four, zero, one, two, three, five, six, eight,
# Nearest to during: mideast, ensuing, authoritarianism, sunga, stenosis, alfa, significant, coalition,
# Nearest to while: calories, unions, partaking, flicker, permissions, messiaen, quito, phocas,
# Nearest to dr: rosenberg, diarists, gilpin, exotics, earl, enlighten, gideon, leland,
# Nearest to nobel: prize, laureate, recipient, boris, mathematician, congressman, myrdal, physiology,
# Nearest to except: heaps, irwin, infield, placename, whitepapers, liliopsida, gallifrey, approval,
# Nearest to animals: infidelity, canadian, wolf, carlow, chordata, mop, ginsberg, burrow,
# Nearest to scale: conjuction, tone, barbecued, inflows, chiba, woodman, spurred, notes,
# Nearest to san: francisco, jose, ccel, mira, california, bakassi, centrosomes, nevada,
# Nearest to mainly: monsanto, lotus, bovines, significance, fueling, gaon, alberti, whitlock,
# Nearest to prince: gustloff, sophia, seating, blacklisting, shaughnessy, lia, desired, citywide,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9604 0.1833 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9727 0.1825 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9355 0.1816 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9742 0.1819 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0213 0.1823 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9071 0.1814 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9573 0.1816 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9488 0.1816 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9564 0.1814 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9533 0.1811 sec/batch
# Nearest to their: headwear, canaanites, ballots, choosing, cephalopods, status, reunited, satirized,
# Nearest to it: is, kittyhawk, crossword, determinative, shores, quadrillion, anticonvulsant, saying,
# Nearest to world: skiing, borman, sonja, queensberry, capital, cass, trust, micah,
# Nearest to an: the, antibody, as, choose, recorded, uphold, thyroid, illegal,
# Nearest to of: the, as, theologically, by, and, sextilis, second, xxxg,
# Nearest to nine: one, zero, four, three, two, six, five, eight,
# Nearest to during: mideast, ensuing, authoritarianism, sunga, stenosis, alfa, rigg, gilman,
# Nearest to while: calories, unions, messiaen, permissions, partaking, avg, flicker, phocas,
# Nearest to dr: rosenberg, diarists, exotics, gilpin, leland, gideon, earl, judaica,
# Nearest to nobel: prize, laureate, recipient, congressman, mathematician, boris, myrdal, physicist,
# Nearest to except: heaps, whitepapers, irwin, approval, gallifrey, placename, infield, indicted,
# Nearest to animals: infidelity, canadian, chordata, carlow, paraphyletic, wolf, burrow, mop,
# Nearest to scale: tone, barbecued, conjuction, inflows, chiba, woodman, spurred, egon,
# Nearest to san: francisco, ccel, jose, mira, bakassi, california, centrosomes, nevada,
# Nearest to mainly: monsanto, lotus, fueling, bovines, alberti, whitlock, cmb, gaon,
# Nearest to prince: gustloff, whom, sophia, seating, navarro, shaughnessy, lia, citywide,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9758 0.1831 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9804 0.1825 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9405 0.1822 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9528 0.1806 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9676 0.1825 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9945 0.1828 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9344 0.1814 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9497 0.1817 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9353 0.1814 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0052 0.1827 sec/batch
# Nearest to their: canaanites, headwear, status, ballots, choosing, cephalopods, molded, reunited,
# Nearest to it: is, shores, kittyhawk, niece, lusitania, quadrillion, determinative, slates,
# Nearest to world: skiing, capital, cass, borman, sonja, nocs, vikings, queensberry,
# Nearest to an: the, antibody, as, uphold, ordained, choose, recorded, illegal,
# Nearest to of: the, and, by, as, external, theologically, with, links,
# Nearest to nine: one, four, zero, two, three, six, eight, seven,
# Nearest to during: mideast, ensuing, authoritarianism, sunga, overthrowing, prussia, occurred, maximilian,
# Nearest to while: calories, unions, permissions, messiaen, flicker, partaking, calorie, avg,
# Nearest to dr: rosenberg, diarists, gideon, gilpin, leland, exotics, earl, judaica,
# Nearest to nobel: prize, laureate, recipient, congressman, boris, myrdal, mathematician, skelton,
# Nearest to except: heaps, whitepapers, irwin, gallifrey, approval, placename, indicted, infield,
# Nearest to animals: infidelity, canadian, carlow, chordata, clothed, burrow, mop, paraphyletic,
# Nearest to scale: inflows, conjuction, barbecued, tone, woodman, spurred, chiba, notes,
# Nearest to san: francisco, ccel, jose, mira, bakassi, centrosomes, chicano, california,
# Nearest to mainly: monsanto, whitlock, bovines, lotus, fueling, alberti, gaon, cmb,
# Nearest to prince: gustloff, sophia, whom, seating, navarro, shaughnessy, citywide, lia,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9307 0.1830 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0608 0.1814 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0111 0.1814 sec/batch
# ...
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8137 0.1812 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8606 0.1817 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8027 0.1837 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8396 0.1817 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8663 0.1822 sec/batch
# Nearest to their: they, canaanites, headwear, ballots, others, in, cephalopods, choosing,
# Nearest to it: is, to, the, which, in, quadrillion, from, and,
# Nearest to world: comes, nocs, skiing, senna, adage, vikings, spaceflights, drops,
# Nearest to an: the, also, a, in, as, and, which, to,
# Nearest to of: the, a, in, and, also, as, is, this,
# Nearest to nine: one, four, zero, six, three, two, five, eight,
# Nearest to during: occurred, mideast, inez, first, thaliana, maximilian, yarmuk, overthrowing,
# Nearest to while: where, avg, washing, permissions, calories, flicker, kitchen, novices,
# Nearest to dr: rosenberg, leland, geisel, exotics, lawmakers, diarists, enlighten, jovis,
# Nearest to nobel: prize, laureate, recipient, coolant, myrdal, humanitarians, bladder, physiology,
# Nearest to except: before, infield, gallifrey, collected, rubicon, placename, whitepapers, coll,
# Nearest to animals: infidelity, zoologists, concert, wolf, chordata, morrow, vilas, burrow,
# Nearest to scale: tone, conjuction, dorian, woodman, spurred, notes, diatonic, ounces,
# Nearest to san: francisco, jose, california, chicano, ccel, concentric, angeles, unlocked,
# Nearest to mainly: monsanto, bovines, embracing, fueling, idiom, whitlock, kroon, early,
# Nearest to prince: acceded, miya, citywide, shaughnessy, dy, navarro, sophia, presented,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8065 0.1825 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8275 0.1817 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8152 0.1809 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8304 0.1817 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8305 0.1819 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8306 0.1811 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8407 0.1812 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.7964 0.1817 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8266 0.1808 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8081 0.1817 sec/batch
# Nearest to their: they, canaanites, headwear, others, in, status, ballots, cephalopods,
# Nearest to it: is, in, the, to, which, and, quadrillion, crossword,
# Nearest to world: comes, nocs, senna, skiing, monuc, sponsorship, in, cass,
# Nearest to an: the, a, also, in, as, by, and, which,
# Nearest to of: the, a, and, by, in, also, as, this,
# Nearest to nine: one, four, zero, three, six, two, five, seven,
# Nearest to during: occurred, maximilian, first, mideast, the, until, inez, yarmuk,
# Nearest to while: where, avg, permissions, washing, kitchen, calories, baptised, novices,
# Nearest to dr: rosenberg, leland, lawmakers, geisel, jovis, satr, exotics, enlighten,
# Nearest to nobel: prize, laureate, recipient, humanitarians, myrdal, physiology, coolant, bladder,
# Nearest to except: rubicon, before, gallifrey, placename, whitepapers, collected, infield, approval,
# Nearest to animals: infidelity, concert, wolf, zoologists, vilas, miscellaneous, chordata, classifies,
# Nearest to scale: tone, conjuction, dorian, woodman, spurred, ounces, swnt, pollinator,
# Nearest to san: francisco, jose, california, concentric, ccel, chicano, angeles, santander,
# Nearest to mainly: bovines, monsanto, embracing, idiom, ultimately, early, leptis, fueling,
# Nearest to prince: acceded, miya, sophia, shaughnessy, citywide, navarro, gustloff, throne,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8083 0.1833 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8265 0.1819 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8028 0.1816 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8110 0.1812 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8933 0.1820 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8028 0.1823 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9263 0.1814 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8500 0.1812 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8753 0.1812 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7954 0.1817 sec/batch
# Nearest to their: they, others, canaanites, in, ballots, headwear, destroyers, status,
# Nearest to it: to, is, in, the, which, quadrillion, although, saying,
# Nearest to world: comes, monuc, senna, skiing, nocs, in, drops, cass,
# Nearest to an: the, in, also, a, and, by, as, predominantly,
# Nearest to of: the, and, in, by, a, also, as, on,
# Nearest to nine: one, four, zero, six, two, three, seven, five,
# Nearest to during: occurred, first, maximilian, inez, mideast, the, began, stayed,
# Nearest to while: avg, where, permissions, washing, calories, baptised, risch, kitchen,
# Nearest to dr: rosenberg, leland, lawmakers, geisel, satr, exotics, jovis, gideon,
# Nearest to nobel: prize, laureate, recipient, bladder, physiology, humanitarians, myrdal, coolant,
# Nearest to except: placename, gallifrey, rubicon, collected, before, infield, approval, whitepapers,
# Nearest to animals: infidelity, concert, vilas, wolf, zoologists, morrow, chordata, classifies,
# Nearest to scale: tone, conjuction, dorian, notes, ounces, spurred, diatonic, swnt,
# Nearest to san: francisco, jose, california, concentric, chicano, ccel, angeles, unlocked,
# Nearest to mainly: embracing, monsanto, bovines, idiom, leptis, ultimately, feces, whitlock,
# Nearest to prince: acceded, miya, sophia, shaughnessy, navarro, citywide, dy, kinematic,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7678 0.1820 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8493 0.1814 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7543 0.1819 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8444 0.1825 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8069 0.1814 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8426 0.1819 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8853 0.1034 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.7800 0.1808 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.7918 0.1809 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8074 0.1817 sec/batch
# Nearest to their: they, canaanites, others, ballots, headwear, in, reunited, kabuki,
# Nearest to it: to, is, the, quadrillion, in, which, and, neanderthalensis,
# Nearest to world: comes, senna, skiing, moon, cass, upsets, drops, monuc,
# Nearest to an: the, in, a, also, and, to, as, by,
# Nearest to of: the, and, in, a, as, by, on, also,
# Nearest to nine: one, four, six, zero, two, seven, three, five,
# Nearest to during: occurred, first, the, maximilian, inez, until, stayed, yarmuk,
# Nearest to while: where, washing, a, avg, baptised, calories, novices, permissions,
# Nearest to dr: rosenberg, lawmakers, leland, geisel, satr, jovis, exotics, nepal,
# Nearest to nobel: prize, laureate, recipient, bladder, albers, humanitarians, coolant, myrdal,
# Nearest to except: gallifrey, rubicon, collected, approval, infield, before, placename, whitepapers,
# Nearest to animals: infidelity, concert, wolf, vilas, zoologists, morrow, classifies, animal,
# Nearest to scale: tone, ounces, conjuction, dorian, scales, diatonic, notes, swnt,
# Nearest to san: francisco, jose, california, concentric, angeles, chicano, ccel, santander,
# Nearest to mainly: monsanto, bovines, embracing, idiom, whitlock, early, fueling, kroon,
# Nearest to prince: acceded, miya, sophia, kinematic, shaughnessy, navarro, gustloff, dy,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7556 0.1822 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8147 0.1806 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8162 0.1812 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7527 0.1812 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8098 0.1809 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8024 0.1809 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8325 0.1820 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7064 0.1814 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7877 0.1819 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7421 0.1814 sec/batch
# Nearest to their: they, others, ballots, cephalopods, headwear, perform, canaanites, of,
# Nearest to it: is, in, to, the, which, quadrillion, and, then,
# Nearest to world: comes, senna, nocs, skiing, monuc, spaceflights, cass, drops,
# Nearest to an: the, a, also, in, and, to, as, is,
# Nearest to of: the, and, in, as, also, a, is, on,
# Nearest to nine: one, four, zero, six, two, three, five, eight,
# Nearest to during: occurred, first, maximilian, on, inez, the, until, mideast,
# Nearest to while: where, a, permissions, avg, the, washing, calories, baptised,
# Nearest to dr: rosenberg, satr, leland, geisel, exotics, jovis, lawmakers, confirm,
# Nearest to nobel: prize, laureate, recipient, bladder, humanitarians, coolant, albers, myrdal,
# Nearest to except: collected, before, gallifrey, infield, placename, those, rubicon, whitepapers,
# Nearest to animals: infidelity, concert, wolf, vilas, animal, zoologists, chordata, villians,
# Nearest to scale: tone, conjuction, ounces, dorian, scales, reproduces, spurred, diatonic,
# Nearest to san: francisco, jose, california, angeles, santander, concentric, chicano, ccel,
# Nearest to mainly: monsanto, bovines, embracing, idiom, early, fueling, leptis, cmb,
# Nearest to prince: acceded, miya, sophia, kinematic, presented, shaughnessy, dy, gustloff,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7276 0.1823 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8111 0.1816 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8213 0.1811 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7725 0.1816 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7634 0.1811 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8640 0.1812 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8173 0.1812 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7982 0.1822 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.7699 0.1816 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8099 0.1812 sec/batch
# Nearest to their: they, ballots, perform, cephalopods, others, canaanites, customarily, choosing,
# Nearest to it: is, in, to, the, which, and, its, this,
# Nearest to world: comes, senna, nocs, monuc, mayne, cass, sonja, skiing,
# Nearest to an: the, a, also, in, and, as, which, is,
# Nearest to of: the, a, and, also, in, as, by, is,
# Nearest to nine: one, four, six, zero, two, three, seven, eight,
# Nearest to during: occurred, first, maximilian, inez, until, the, thaliana, mideast,
# Nearest to while: where, a, permissions, the, avg, washing, not, calories,
# Nearest to dr: rosenberg, geisel, exotics, leland, enlighten, musically, fund, satr,
# Nearest to nobel: prize, laureate, recipient, humanitarians, bladder, coolant, albers, myrdal,
# Nearest to except: collected, infield, rubicon, before, gallifrey, whitepapers, approval, placename,
# Nearest to animals: infidelity, animal, vilas, concert, wolf, zoologists, chordata, classifies,
# Nearest to scale: tone, conjuction, ounces, dorian, reproduces, scales, swnt, spurred,
# Nearest to san: francisco, california, jose, angeles, concentric, santander, ccel, translocation,
# Nearest to mainly: bovines, monsanto, embracing, early, idiom, to, cmb, midpoint,
# Nearest to prince: acceded, miya, sophia, throne, navarro, nihonshoki, dy, emperor,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8360 0.1844 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8184 0.1812 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7764 0.1808 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8071 0.1808 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8474 0.1820 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8086 0.1817 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.7828 0.1812 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8369 0.1809 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7919 0.1825 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7826 0.1809 sec/batch
# Nearest to their: they, others, of, and, by, were, ballots, headwear,
# Nearest to it: in, is, the, to, which, and, this, neanderthalensis,
# Nearest to world: monuc, comes, senna, nocs, japan, cass, spaceflights, gareth,
# Nearest to an: the, a, in, also, as, and, is, to,
# Nearest to of: the, and, a, by, as, in, also, on,
# Nearest to nine: one, four, six, zero, two, three, seven, eight,
# Nearest to during: occurred, first, until, maximilian, the, witnessed, stayed, yarmuk,
# Nearest to while: where, a, the, in, permissions, not, risch, avg,
# Nearest to dr: rosenberg, geisel, enlighten, lawmakers, jovis, exotics, satr, leland,
# Nearest to nobel: prize, laureate, recipient, humanitarians, bladder, shovel, coolant, albers,
# Nearest to except: rubicon, collected, before, placename, gallifrey, infield, those, heaps,
# Nearest to animals: infidelity, vilas, animal, villians, classifies, zoologists, concert, wolf,
# Nearest to scale: tone, ounces, conjuction, dorian, scales, reproduces, spurred, diatonic,
# Nearest to san: francisco, california, jose, concentric, ccel, angeles, santander, chicano,
# Nearest to mainly: bovines, embracing, monsanto, idiom, early, feces, to, ultimately,
# Nearest to prince: acceded, miya, sophia, navarro, throne, nihonshoki, presented, dy,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8251 0.1825 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7986 0.1828 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8980 0.1820 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9013 0.1822 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8512 0.1816 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.7961 0.1825 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7439 0.1809 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8274 0.1814 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7214 0.1814 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8391 0.1819 sec/batch
# Nearest to their: they, perform, headwear, ballots, canaanites, by, others, loyalty,
# Nearest to it: in, the, to, is, which, and, neanderthalensis, on,
# Nearest to world: comes, senna, monuc, cass, in, nocs, japan, war,
# Nearest to an: the, a, also, in, and, as, which, to,
# Nearest to of: the, a, and, by, as, in, on, also,
# Nearest to nine: one, four, six, zero, seven, two, three, eight,
# Nearest to during: occurred, first, the, virtuoso, until, witnessed, maximilian, on,
# Nearest to while: where, in, the, washing, a, permissions, not, as,
# Nearest to dr: rosenberg, geisel, jovis, lawmakers, exotics, kala, satr, fund,
# Nearest to nobel: prize, laureate, recipient, humanitarians, albers, shovel, bladder, myrdal,
# Nearest to except: rubicon, collected, placename, infield, gallifrey, before, lenition, jana,
# Nearest to animals: infidelity, vilas, concert, classifies, miscellaneous, chordata, villians, zoologists,
# Nearest to scale: tone, dorian, scales, ounces, conjuction, reproduces, swnt, diatonic,
# Nearest to san: francisco, california, jose, angeles, concentric, ccel, santander, chicano,
# Nearest to mainly: monsanto, embracing, bovines, idiom, to, feces, by, kroon,
# Nearest to prince: acceded, miya, sophia, navarro, presented, kinematic, shaughnessy, nihonshoki,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.7866 0.1823 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8027 0.1812 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
